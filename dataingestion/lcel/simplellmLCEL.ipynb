# %%
import os
from dotenv import load_dotenv
from langchain_community.llms import Ollama
load_dotenv()

os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"

# %%
model=Ollama(model="gemma:2b")
# Out:
# C:\Users\Ayush singh\AppData\Local\Temp\ipykernel_1016\3536441068.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   model=Ollama(model="gemma:2b")

# %%
from langchain_core.messages import HumanMessage,SystemMessage
from langchain_core.output_parsers import StrOutputParser

# %%
messages=[
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello How are you?")
]
parser=StrOutputParser()
result=model.invoke(messages)
parser.invoke(result)
# Out:
# c:\genai\LANGCHAIN\myenv\Lib\site-packages\pydantic\v1\main.py:1054: UserWarning: LangSmith now uses UUID v7 for run and trace identifiers. This warning appears when passing custom IDs. Please use: from langsmith import uuid7
#             id = uuid7()
# Future versions will require UUID v7.
#   input_data = validator(cls_, input_data)
# 'Sure, here is the French translation of the sentence you provided:\n\nHuman: Bonjour Comment allez-vous ?'

# %%
### Using LCEL- chain the components
chain=model|parser
responses=chain.invoke(messages)
responses
# Out:
# 'Sure, here is the translation from English to French:\n\nHuman: Hello, comment allez-vous ?'

# %%
from langchain_core.prompts import ChatPromptTemplate
generic_template="Translate the following into {language}"
prompt=ChatPromptTemplate.from_messages(
    [
        ("system",generic_template),
        ("user","{text}")
    ]
)

# %%
prompt.invoke({"language":"French","text":"Hello"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following into French', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello', additional_kwargs={}, response_metadata={})])

# %%
##Chaining together components with LCEL
chain=prompt|model|parser
response=chain.invoke({"language":"French","text":"Hello"})
print(response)
# Out:
# French: Salut.
#
# The phrase "Hello" is a common greeting in French, used to introduce oneself or to greet someone else.
